# %% [markdown]
# <a href="https://colab.research.google.com/github/RudraKhare/British-Airways-Internship/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# Out:
# ...
# 228813984/228813984 [==============================] - 2s 0us/step

# %%
data_dir
# Out:
# './datasets/flower_photos'

# %%
import pathlib
data_dir=pathlib.Path(data_dir)
data_dir
# Out:
# PosixPath('datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))
# Out:
# [PosixPath('datasets/flower_photos/tulips/8712260079_c0ff42e0e2_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/113291410_1bdc718ed8_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/440714501_9f8268e1b0.jpg'),
#  PosixPath('datasets/flower_photos/tulips/5637140035_e6c5514f54.jpg'),
#  PosixPath('datasets/flower_photos/tulips/18245124970_e68fd3f3c3.jpg'),
#  PosixPath('datasets/flower_photos/tulips/135994133_4f306fe4bf_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/8712270665_57b5bda0a2_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/8623170936_83f4152431.jpg'),
#  PosixPath('datasets/flower_photos/tulips/9976515506_d496c5e72c.jpg'),
#  PosixPath('datasets/flower_photos/tulips/13472393854_b2530f7029_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/17199499591_67b64b21ed_m.jpg'),
#  PosixPath('datasets/flower_photos/tulips/13529687904_3d60abb479_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/15029962436_3e50c1f30f_n.jpg'),
# ...

# %%
image_count=len(list(data_dir.glob('*/*.jpg')))

# %%
image_count
# Out:
# 3670

# %%
roses=list(data_dir.glob('roses/*'))
roses
# Out:
# [PosixPath('datasets/flower_photos/roses/4267024012_295e7141a3_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/4414135084_1ac7e6cd54.jpg'),
#  PosixPath('datasets/flower_photos/roses/509239741_28e2cfe492_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/494803274_f84f21d53a.jpg'),
#  PosixPath('datasets/flower_photos/roses/3621011057_0d03bd171b_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/6241886381_cc722785af.jpg'),
#  PosixPath('datasets/flower_photos/roses/15681454551_b6f73ce443_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/9298314004_c1a8146521.jpg'),
#  PosixPath('datasets/flower_photos/roses/9433167170_fa056d3175.jpg'),
#  PosixPath('datasets/flower_photos/roses/3026375835_a20ecdd140_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/8125886145_ae99f91fd0.jpg'),
#  PosixPath('datasets/flower_photos/roses/15951588433_c0713cbfc6_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/17040847367_b54d05bf52.jpg'),
# ...

# %%
pip install pillow

# %%
pip install opencv-python

# %%
PIL .Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x229>

# %%
PIL.Image.open(str(roses[2]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=179x240>

# %%
tulips=list(data_dir.glob('tulips/*'))

# %%
PIL.Image.open(str(tulips[2]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x380>

# %%
flowers_image_dict={
    'roses':list(data_dir.glob('roses/*')),
    'daisy':list(data_dir.glob('daisy/*')),
    'dandelion':list(data_dir.glob('dandelion/*')),
    'sunflowers':list(data_dir.glob('sunflowers/*')),
    'tulips':list(data_dir.glob('tulips/*'))
}

# %%
flowers_image_dict['daisy']
# Out:
# [PosixPath('datasets/flower_photos/daisy/6054952060_c88612f3c5_n.jpg'),
#  PosixPath('datasets/flower_photos/daisy/4581199679_867652c3f1_n.jpg'),
#  PosixPath('datasets/flower_photos/daisy/2077865117_9ed85191ae_n.jpg'),
#  PosixPath('datasets/flower_photos/daisy/2889325612_f2fc403ff0_m.jpg'),
#  PosixPath('datasets/flower_photos/daisy/3415180846_d7b5cced14_m.jpg'),
#  PosixPath('datasets/flower_photos/daisy/15760153042_a2a90e9da5_m.jpg'),
#  PosixPath('datasets/flower_photos/daisy/15327813273_06cdf42210.jpg'),
#  PosixPath('datasets/flower_photos/daisy/14600779226_7bbc288d40_m.jpg'),
#  PosixPath('datasets/flower_photos/daisy/8718637649_87a0d85190_n.jpg'),
#  PosixPath('datasets/flower_photos/daisy/19813618946_93818db7aa_m.jpg'),
#  PosixPath('datasets/flower_photos/daisy/163978992_8128b49d3e_n.jpg'),
#  PosixPath('datasets/flower_photos/daisy/6089825811_80f253fbe1.jpg'),
#  PosixPath('datasets/flower_photos/daisy/488202750_c420cbce61.jpg'),
# ...

# %%
flowers_labels_dict={
    'roses':0,
    'daisy':1,
    'dandelions':2,
    'sunflowers':3,
    'tulips':4,
}

# %%
img=cv2.imread(str(flowers_image_dict['roses'][0]))
img.shape
# Out:
# (229, 320, 3)

# %%
cv2.resize(img,(100,100)).shape
# Out:
# (100, 100, 3)

# %%
import os

# %%
X,y= [], []

for flower_name in flowers_image_dict.keys():
  for image in flowers_image_dict[flower_name]:
    img=cv2.imread(str(image))
    resized_img=cv2.resize(img,(180,180))
    X.append(resized_img)
    y.append(flower_name)
